# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.dpi'] = 300

import sys
sys.path.insert(0, 'test_functions')
# %load_ext autoreload
# %autoreload 2
# %aimport tld
import tld

import pandas as pd

# %% [markdown]
# # INPUT TEST DIRECTORY

# %%
test_directory = "test_images/"

# %% [markdown]
# # TEST DATASET

# %%
tld.main(test_directory, "four_class")
# Out:
# '================== GENERAL PERFORMANCE =================='
# 'Accuracy: 0.08'
# 'PPV: 0.25'
# 'Sensitivity: 0.08'
# 'F1-Score: 0.12'
# 'G-mean: 0.24'
# '========================================================='
# '================= PER LABEL PERFORMANCE ================='
#        label  sensitivity  specificity  ppv       npv
# 0  bacterial     0.000000     0.555556  0.0  0.625000
# 1     normal     0.000000     0.777778  0.0  0.700000
# 2      viral     0.333333     1.000000  1.0  0.818182
# 3      covid     0.000000     0.444444  0.0  0.571429
# '========================================================='
